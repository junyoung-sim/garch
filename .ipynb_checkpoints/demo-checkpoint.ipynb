# %% [markdown]
# ### ARCH (Autoregressive Conditional Heteroskedasticity)
#
# $y_{t}=\frac{x_{t} - x_{t-1}}{x_{t-1}}$ (returns)
#
# $\sigma_{t}^2 = \frac{1}{t}\sum_{i=1}^{t}(y_{t}-\bar{y})^2=\frac{1}{t}\sum_{i=1}^{t}y_{t}^2=\frac{1}{1}\sum_{i=1}^{1}y_{t}^2=y_{t}^2$ (variance or volatility of $y_{t}$; mean returns is zero and only one observation is possible)
#
# ARCH(p) describes an ARCH model with p lags. The simplest model would be ARCH(1) as follows.
#
# (1) $\sigma_{t}^2=\alpha_{0}+\alpha_{1}y_{t-1}^2$ (volatility of $y_{t}$ is conditional on $y_{t-1}$; may add more terms for more lags)
#
# (2) $y_{t}=\sigma_{t}\epsilon_{t}=\epsilon_{t}\sqrt{\alpha_{0}+\alpha_{1}y_{t-1}^2}$
#
# (3) $y_{t}^2=\alpha_{0}+\alpha_{1}y_{t-1}^2+\epsilon_{t}$
#
# $\epsilon_{t} \sim N(\mu=0,\sigma^2=1)$ (error)
#
# ### GARCH (Generalized ARCH)
#
# GARCH improves ARCH by including volatility from the previous time step in the current volatility term such that the causal relationship between periods of high or low volatility are considered.
#
# GARCH(p, q) describes an GARCH model with p-order of $\sigma^2$ and q-order of $y_{t}$. The simplest model would be GARCH(1,1) as follows.
#
# (1) $\sigma_{t}^2=\alpha_{0}+\alpha_{1}y_{t-1}^2+\beta_{1}\sigma_{t-1}^2$
#
# (2) $y_{t}=\sigma_{t}\epsilon_{t}=\epsilon_{t}\sqrt{\alpha_{0}+\alpha_{1}y_{t-1}^2+\beta_{1}\sigma_{t-1}^2}$
#
# (3) $y_{t}^2=\alpha_{0}+\alpha_{1}y_{t-1}^2+\beta_{1}\sigma_{t-1}^2+\epsilon_{t}$
#
# $\epsilon_{t} \sim N(\mu=0,\sigma^2=1)$ (error)
#
# When modeling stationary time series with ARCH and GARCH models, $y_{0}$ may be set to whatever value the time series of interest starts from, but the initial volatility term is $\sigma_{0}=0$. Coefficients can be estimated using least squares
#
# #### Conditions
# (1) Time series must be stationary at a mean of zero.
#
# (2) Time series must exhibit periods of similar volatility.
#
# (3) Use the PACF (Partial Autocorrelation Function) to find the appropriate number of lags. PACF yields the correlation between lagged values within a stationary time series.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_pacf
from arch import arch_model
from download import download

apikey = open("apikey", "r").readline()

# %%
ticker = input("Ticker: ")
dat = download(ticker, apikey)
print(dat)
# Out:
# Ticker: SPY
#             date  adjClose
# 0     2000-01-03     94.60
# 1     2000-01-04     90.90
# 2     2000-01-05     91.06
# 3     2000-01-06     89.59
# 4     2000-01-07     94.80
# ...          ...       ...
# 5940  2023-08-14    448.11
# 5941  2023-08-15    442.89
# 5942  2023-08-16    439.64
# 5943  2023-08-17    436.29
# 5944  2023-08-18    436.47
#
# [5945 rows x 2 columns]

# %%
t0 = np.array(dat["adjClose"].iloc[0:-1])
t1 = np.array(dat["adjClose"].iloc[1:])

returns = (t1 - t0) / t0
print(pd.DataFrame(returns).describe())
# Out:
#                  0
# count  5944.000000
# mean      0.000334
# std       0.012420
# min      -0.109450
# 25%      -0.004813
# 50%       0.000648
# 75%       0.006025
# max       0.145178

# %%
ax = sns.histplot(data=returns, binwidth=np.std(returns), stat="probability")
ax.set(xlabel="{} P&L" .format(ticker), ylabel="Frequency")
# Out:
# [Text(0.5, 0, 'SPY P&L'), Text(0, 0.5, 'Frequency')]

# %%
plt.plot(returns)
plt.xlabel("t")
plt.ylabel("Daily Return")
plt.show()

# %%
plot_pacf(returns**2)
plt.show()

# %% [markdown]
# Correlation is obviously 1.00 with no lag. Besides that, the first two lags seem to be of significance. Let's try GARCH(2,2).

# %%
model = arch_model(returns, p=2,q=2)

# %%
model.fit().summary()
# Out:
# Iteration:      1,   Func. Count:      8,   Neg. LLF: 7.141070058663659e+22
# Iteration:      2,   Func. Count:     25,   Neg. LLF: 67749718373.11176
# Iteration:      3,   Func. Count:     41,   Neg. LLF: 46066819.04904397
# Iteration:      4,   Func. Count:     56,   Neg. LLF: 8428840462185368.0
# Iteration:      5,   Func. Count:     73,   Neg. LLF: 1.8183007880512662e+19
# Iteration:      6,   Func. Count:     88,   Neg. LLF: 7.023313735501704e+25
# Iteration:      7,   Func. Count:    105,   Neg. LLF: 2125921194873.6724
# Iteration:      8,   Func. Count:    122,   Neg. LLF: 150599.31398312913
# Iteration:      9,   Func. Count:    136,   Neg. LLF: 4.878965656570751e+18
# Iteration:     10,   Func. Count:    153,   Neg. LLF: 2667975418822.5537
# Iteration:     11,   Func. Count:    169,   Neg. LLF: -19145.905580047238
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -19145.905575644225
#             Iterations: 15
#             Function evaluations: 169
#             Gradient evaluations: 11
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:                19145.9
# Distribution:                  Normal   AIC:                          -38279.8
# Method:            Maximum Likelihood   BIC:                          -38239.7
#                                         No. Observations:                 5944
# Date:                Fri, Aug 18 2023   Df Residuals:                     5943
# Time:                        17:28:42   Df Model:                            1
#                                  Mean Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# mu         7.2986e-04  1.350e-04      5.407  6.424e-08 [4.653e-04,9.944e-04]
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega      3.0851e-06  2.306e-11  1.338e+05      0.000 [3.085e-06,3.085e-06]
# alpha[1]       0.1000  2.230e-02      4.484  7.309e-06   [5.629e-02,  0.144]
# alpha[2]       0.1000  8.222e-02      1.216      0.224  [-6.116e-02,  0.261]
# beta[1]        0.3900      0.657      0.593      0.553     [ -0.898,  1.678]
# beta[2]        0.3900      0.587      0.664      0.507     [ -0.761,  1.541]
# ============================================================================
#
# Covariance estimator: robust
# """

# %% [markdown]
# Only $\alpha_{1}$ seems to be significant at a p-value of 7.309e-06. Let's try ARCH(1)

# %%
model = arch_model(returns, p=1, q=0)

# %%
model.fit().summary()
# Out:
# Iteration:      1,   Func. Count:      5,   Neg. LLF: 1.940517314953763e+22
# Iteration:      2,   Func. Count:     17,   Neg. LLF: -17985.215507455385
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -17985.215485867695
#             Iterations: 6
#             Function evaluations: 17
#             Gradient evaluations: 2
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                       Constant Mean - ARCH Model Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                       ARCH   Log-Likelihood:                17985.2
# Distribution:                  Normal   AIC:                          -35964.4
# Method:            Maximum Likelihood   BIC:                          -35944.4
#                                         No. Observations:                 5944
# Date:                Fri, Aug 18 2023   Df Residuals:                     5943
# Time:                        17:28:42   Df Model:                            1
#                                  Mean Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# mu         6.2295e-04  1.660e-04      3.754  1.742e-04 [2.977e-04,9.482e-04]
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega      7.7116e-05  2.485e-06     31.030 2.124e-211 [7.225e-05,8.199e-05]
# alpha[1]       0.2000  2.501e-02      7.997  1.280e-15     [  0.151,  0.249]
# ============================================================================
#
# Covariance estimator: robust
# """

# %%
yhat = np.sqrt(model.fit(disp="off").forecast(horizon=5).variance.values[-1,:])
plt.plot(yhat)
plt.show()

# %% [markdown]
# Volatility expected to increase.
